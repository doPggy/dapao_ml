# %%
import matplotlib.pyplot as plt
import numpy as np
import math

# %%
fig, ax = plt.subplots()
ax.plot([1, 2, 3, 4], [1, 4, 2, 3])
plt.plot([1, 2, 3, 4], [1, 4, 2, 3])

# %%
x = np.linspace(0, 2, 300)
# plt.plot(x, x, label = 'linear')
plt.plot(x, np.sin(x ** 3 + x), label = 'quadratic')
# plt.plot(x, x ** 3, label = 'cubic')
plt.xlabel('x')
plt.ylabel('y')
plt.title('caonima')
# plt.legend()
plt.show()
